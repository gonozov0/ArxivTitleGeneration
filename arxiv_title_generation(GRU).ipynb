# %% [markdown]
# # Генерация заголовков научных статей: слабый baseline

# %%
from google.colab import drive
drive.mount('/content/drive')

root_dir = '.drive/My Drive/'

# %cd './drive/My Drive/Colab Notebooks/arxiv_title_generation'
# !ls
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# /content/drive/My Drive/Colab Notebooks/arxiv_title_generation
# cache  input  output  sample_submission.csv  submission.csv  vocs.pkl

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchtext.data import Field, BucketIterator

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import spacy

import random
import math
import time

# %%
SEED = 1234

random.seed(SEED)
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %%
spacy_en = spacy.load('en')

# %%
def tokenize(text):
    """
    Tokenizes English text from a string into a list of strings (tokens)
    """
    return [tok.text for tok in spacy_en.tokenizer(text) if not tok.text.isspace()]

# %%
from torchtext import data, vocab

tokenizer = data.get_tokenizer('spacy')
TEXT = Field(tokenize=tokenize,
            init_token = '<sos>', 
            eos_token = '<eos>', 
            include_lengths = True,
            lower = True)

# %%
# let's train model on a part of train.csv to speed up computations

# import pandas as pd

# train_df = pd.read_csv('/kaggle/input/title-generation/train.csv').head(30001)
# train_df.to_csv('/kaggle/working/train_small.csv', index=False)

# %%
# %%time
trn_data_fields = [("src", TEXT),
                   ("trg", TEXT)]

dataset = data.TabularDataset(
    path='input/train.csv',
    format='csv',
    skip_header=True,
    fields=trn_data_fields
)


train_data, valid_data = dataset.split(split_ratio=[0.99, 0.01])
# Out:
# CPU times: user 1min 49s, sys: 1.39 s, total: 1min 50s
# Wall time: 1min 51s

# %%
TEXT.build_vocab(train_data, min_freq = 7)
print(f"Unique tokens in vocabulary: {len(TEXT.vocab)}")
# Out:
# Unique tokens in vocabulary: 40730

# %%
BATCH_SIZE = 32

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

train_iterator, valid_iterator = BucketIterator.splits(
    (train_data, valid_data), 
     batch_size = BATCH_SIZE,
     sort_within_batch = True,
     sort_key = lambda x : len(x.src),
     device = device)

# %%
class Encoder(nn.Module):
    def __init__(self, input_dim, emb_dim, enc_hid_dim, dec_hid_dim, dropout):
        super().__init__()
        
        self.embedding = nn.Embedding(input_dim, emb_dim)
        
        self.rnn = nn.GRU(emb_dim, enc_hid_dim, bidirectional = True)
        
        self.fc = nn.Linear(enc_hid_dim * 2, dec_hid_dim)
        
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, src, src_len):
        
        #src = [src sent len, batch size]
        #src_len = [src sent len]
        
        embedded = self.dropout(self.embedding(src))
        
        #embedded = [src sent len, batch size, emb dim]
                
        packed_embedded = nn.utils.rnn.pack_padded_sequence(embedded, src_len)
                
        packed_outputs, hidden = self.rnn(packed_embedded)
                                 
        #packed_outputs is a packed sequence containing all hidden states
        #hidden is now from the final non-padded element in the batch
            
        outputs, _ = nn.utils.rnn.pad_packed_sequence(packed_outputs) 
            
        #outputs is now a non-packed sequence, all hidden states obtained
        #  when the input is a pad token are all zeros
            
        #outputs = [sent len, batch size, hid dim * num directions]
        #hidden = [n layers * num directions, batch size, hid dim]
        
        #hidden is stacked [forward_1, backward_1, forward_2, backward_2, ...]
        #outputs are always from the last layer
        
        #hidden [-2, :, : ] is the last of the forwards RNN 
        #hidden [-1, :, : ] is the last of the backwards RNN
        
        #initial decoder hidden is final hidden state of the forwards and backwards 
        #  encoder RNNs fed through a linear layer
        hidden = torch.tanh(self.fc(torch.cat((hidden[-2,:,:], hidden[-1,:,:]), dim = 1)))
        
        #outputs = [sent len, batch size, enc hid dim * 2]
        #hidden = [batch size, dec hid dim]
        
        return outputs, hidden

# %%
class Attention(nn.Module):
    def __init__(self, enc_hid_dim, dec_hid_dim):
        super().__init__()
        
        self.attn = nn.Linear((enc_hid_dim * 2) + dec_hid_dim, dec_hid_dim)
        self.v = nn.Parameter(torch.rand(dec_hid_dim))
        
    def forward(self, hidden, encoder_outputs, mask):
        
        #hidden = [batch size, dec hid dim]
        #encoder_outputs = [src sent len, batch size, enc hid dim * 2]
        #mask = [batch size, src sent len]
        
        batch_size = encoder_outputs.shape[1]
        src_len = encoder_outputs.shape[0]
        
        #repeat encoder hidden state src_len times
        hidden = hidden.unsqueeze(1).repeat(1, src_len, 1)
        
        encoder_outputs = encoder_outputs.permute(1, 0, 2)
        
        #hidden = [batch size, src sent len, dec hid dim]
        #encoder_outputs = [batch size, src sent len, enc hid dim * 2]
        
        energy = torch.tanh(self.attn(torch.cat((hidden, encoder_outputs), dim = 2))) 
        
        #energy = [batch size, src sent len, dec hid dim]
                
        energy = energy.permute(0, 2, 1)
        
        #energy = [batch size, dec hid dim, src sent len]
        
        #v = [dec hid dim]
        
        v = self.v.repeat(batch_size, 1).unsqueeze(1)
        
        #v = [batch size, 1, dec hid dim]
            
        attention = torch.bmm(v, energy).squeeze(1)
        # print(attention.shape)
        # print(mask.shape)
        #attention = [batch size, src sent len]
        
        attention = attention.masked_fill(mask == 0, -1e10)
        # print(attention.shape)
        
        return F.softmax(attention, dim = 1)

# %%
class Decoder(nn.Module):
    def __init__(self, output_dim, emb_dim, enc_hid_dim, dec_hid_dim, dropout, attention):
        super().__init__()

        self.output_dim = output_dim
        self.attention = attention
        
        self.embedding = nn.Embedding(output_dim, emb_dim)
        
        self.rnn = nn.GRU((enc_hid_dim * 2) + emb_dim, dec_hid_dim)
        
        self.out = nn.Linear((enc_hid_dim * 2) + dec_hid_dim + emb_dim, output_dim)
        
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, input, hidden, encoder_outputs, mask):
             
        #input = [batch size]
        #hidden = [batch size, dec hid dim]
        #encoder_outputs = [src sent len, batch size, enc hid dim * 2]
        #mask = [batch size, src sent len]
        
        input = input.unsqueeze(0)
        
        #input = [1, batch size]
        
        embedded = self.dropout(self.embedding(input))
        
        #embedded = [1, batch size, emb dim]
        
        a = self.attention(hidden, encoder_outputs, mask)
                
        #a = [batch size, src sent len]
        
        a = a.unsqueeze(1)
        
        #a = [batch size, 1, src sent len]
        
        encoder_outputs = encoder_outputs.permute(1, 0, 2)
        
        #encoder_outputs = [batch size, src sent len, enc hid dim * 2]
        
        weighted = torch.bmm(a, encoder_outputs)
        
        #weighted = [batch size, 1, enc hid dim * 2]
        
        weighted = weighted.permute(1, 0, 2)
        
        #weighted = [1, batch size, enc hid dim * 2]
        
        rnn_input = torch.cat((embedded, weighted), dim = 2)
        
        #rnn_input = [1, batch size, (enc hid dim * 2) + emb dim]
            
        output, hidden = self.rnn(rnn_input, hidden.unsqueeze(0))
        
        #output = [sent len, batch size, dec hid dim * n directions]
        #hidden = [n layers * n directions, batch size, dec hid dim]
        
        #sent len, n layers and n directions will always be 1 in this decoder, therefore:
        #output = [1, batch size, dec hid dim]
        #hidden = [1, batch size, dec hid dim]
        #this also means that output == hidden
        assert (output == hidden).all()
        
        embedded = embedded.squeeze(0)
        output = output.squeeze(0)
        weighted = weighted.squeeze(0)
        
        output = self.out(torch.cat((output, weighted, embedded), dim = 1))
        
        #output = [bsz, output dim]
        
        return output, hidden.squeeze(0), a.squeeze(1)

# %%
class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder, pad_idx, sos_idx, eos_idx, device):
        super().__init__()
        
        self.encoder = encoder
        self.decoder = decoder
        self.pad_idx = pad_idx
        self.sos_idx = sos_idx
        self.eos_idx = eos_idx
        self.device = device
        
    def create_mask(self, src):
        mask = (src != self.pad_idx).permute(1, 0)
        return mask
        
    def forward(self, src, src_len, trg, teacher_forcing_ratio = 0.5):
        
        #src = [src sent len, batch size]
        #src_len = [batch size]
        #trg = [trg sent len, batch size]
        #teacher_forcing_ratio is probability to use teacher forcing
        #e.g. if teacher_forcing_ratio is 0.75 we use teacher forcing 75% of the time
        
        if trg is None:
            assert teacher_forcing_ratio == 0, "Must be zero during inference"
            inference = True
            trg = torch.zeros((100, src.shape[1])).long().fill_(self.sos_idx).to(src.device)
        else:
            inference = False
            
        batch_size = src.shape[1]
        max_len = trg.shape[0]
        trg_vocab_size = self.decoder.output_dim
        
        #tensor to store decoder outputs
        outputs = torch.zeros(max_len, batch_size, trg_vocab_size).to(self.device)
        
        #tensor to store attention
        attentions = torch.zeros(max_len, batch_size, src.shape[0]).to(self.device)
        
        #encoder_outputs is all hidden states of the input sequence, back and forwards
        #hidden is the final forward and backward hidden states, passed through a linear layer
        encoder_outputs, hidden = self.encoder(src, src_len)
                
        #first input to the decoder is the <sos> tokens
        input = trg[0,:]
        
        mask = self.create_mask(src)
                
        #mask = [batch size, src sent len]
                
        for t in range(1, max_len):
            
            #insert input token embedding, previous hidden state, all encoder hidden states 
            # and mask
            #receive output tensor (predictions), new hidden state and attention tensor
            output, hidden, attention = self.decoder(input, hidden, encoder_outputs, mask)
            
            #place predictions in a tensor holding predictions for each token
            outputs[t] = output
            
            #place attentions in a tensor holding attention value for each input token
            attentions[t] = attention
            
            #decide if we are going to use teacher forcing or not
            teacher_force = random.random() < teacher_forcing_ratio
            
            #get the highest predicted token from our predictions
            top1 = output.argmax(1) 
            
            #if teacher forcing, use actual next token as next input
            #if not, use predicted token
            input = trg[t] if teacher_force else top1
            
            #if doing inference and next token/prediction is an eos token then stop
            if inference and input.item() == self.eos_idx:
                return outputs[:t], attentions[:t]
            
        return outputs, attentions

# %%
INPUT_DIM = len(TEXT.vocab) #40710
OUTPUT_DIM = len(TEXT.vocab) #40710
ENC_EMB_DIM = 128
DEC_EMB_DIM = 128
ENC_HID_DIM = 64
DEC_HID_DIM = 64
ENC_DROPOUT = 0.8
DEC_DROPOUT = 0.8
PAD_IDX = TEXT.vocab.stoi['<pad>']
SOS_IDX = TEXT.vocab.stoi['<sos>']
EOS_IDX = TEXT.vocab.stoi['<eos>']

attn = Attention(ENC_HID_DIM, DEC_HID_DIM)
enc = Encoder(INPUT_DIM, ENC_EMB_DIM, ENC_HID_DIM, DEC_HID_DIM, ENC_DROPOUT)
dec = Decoder(OUTPUT_DIM, DEC_EMB_DIM, ENC_HID_DIM, DEC_HID_DIM, DEC_DROPOUT, attn)

model = Seq2Seq(enc, dec, PAD_IDX, SOS_IDX, EOS_IDX, device).to(device)

# %%
def init_weights(m):
    for name, param in m.named_parameters():
        if 'weight' in name:
            nn.init.normal_(param.data, mean=0, std=0.01)
        else:
            nn.init.constant_(param.data, 0)
            
model.apply(init_weights)
# Out:
# Seq2Seq(
#   (encoder): Encoder(
#     (embedding): Embedding(40730, 128)
#     (rnn): GRU(128, 64, bidirectional=True)
#     (fc): Linear(in_features=128, out_features=64, bias=True)
#     (dropout): Dropout(p=0.8, inplace=False)
#   )
#   (decoder): Decoder(
#     (attention): Attention(
#       (attn): Linear(in_features=192, out_features=64, bias=True)
#     )
#     (embedding): Embedding(40730, 128)
#     (rnn): GRU(256, 64)
#     (out): Linear(in_features=320, out_features=40730, bias=True)
#     (dropout): Dropout(p=0.8, inplace=False)
#   )
# )

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 23,658,202 trainable parameters

# %%
optimizer = optim.Adam(model.parameters())

# %%
criterion = nn.CrossEntropyLoss(ignore_index = PAD_IDX)

# %% [markdown]
# ### Обучение модели

# %%
import matplotlib
matplotlib.rcParams.update({'figure.figsize': (16, 12), 'font.size': 14})
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import clear_output


def train(model, iterator, optimizer, criterion, clip, train_history=None, valid_history=None):
    
    model.train()
    
    epoch_loss = 0
    history = []
    for i, batch in enumerate(iterator):
        
        src, src_len = batch.src
        trg, trg_len = batch.trg
        
        optimizer.zero_grad()
        
        output, attetion = model(src, src_len, trg)
        
        #trg = [trg sent len, batch size]
        #output = [trg sent len, batch size, output dim]
        
        output = output[1:].view(-1, output.shape[-1])
        trg = trg[1:].view(-1)
        
        #trg = [(trg sent len - 1) * batch size]
        #output = [(trg sent len - 1) * batch size, output dim]
        
        loss = criterion(output, trg)
        
        loss.backward()
        
        torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
        
        optimizer.step()
        
        epoch_loss += loss.item()
        
        history.append(loss.cpu().data.numpy())
        if (i+1)%10==0:
            fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12, 8))

            clear_output(True)
            ax[0].plot(history, label='train loss')
            ax[0].set_xlabel('Batch')
            ax[0].set_title('Train loss')
            if train_history is not None:
                ax[1].plot(train_history, label='general train history')
                ax[1].set_xlabel('Epoch')
            if valid_history is not None:
                ax[1].plot(valid_history, label='general valid history')
            plt.legend()
            
            plt.show()
        
    return epoch_loss / len(iterator)

# %%
def evaluate(model, iterator, criterion):
    
    model.eval()
    
    epoch_loss = 0
    
    with torch.no_grad():
    
        for i, batch in enumerate(iterator):

            src, src_len = batch.src
            trg, trg_len = batch.trg

            output, attention = model(src, src_len, trg, 0) #turn off teacher forcing

            #trg = [trg sent len, batch size]
            #output = [trg sent len, batch size, output dim]

            output = output[1:].view(-1, output.shape[-1])
            trg = trg[1:].view(-1)

            #trg = [(trg sent len - 1) * batch size]
            #output = [(trg sent len - 1) * batch size, output dim]

            loss = criterion(output, trg)

            epoch_loss += loss.item()
        
    return epoch_loss / len(iterator)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
MODEL_NAME = 'cache/best_model_dict_gru_gru.pt'

# %%
# to get results like in leaderboard train the model
# for 10 epochs on the whole dataset (135000 samples instead of 30000)

N_EPOCHS = 14
CLIP = 1

train_history = []
valid_history = []

# best_valid_loss = float('inf')
best_valid_loss = 5.445

for epoch in range(N_EPOCHS):
    
    start_time = time.time()
    
    train_loss = train(model, train_iterator, optimizer, criterion, CLIP, train_history, valid_history)
    valid_loss = evaluate(model, valid_iterator, criterion)
    
    end_time = time.time()
    
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), MODEL_NAME)
        
        
    train_history.append(train_loss)
    valid_history.append(valid_loss)
    
    print(f'Epoch: {epoch+1:02} | Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train PPL: {math.exp(train_loss):7.3f}')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. PPL: {math.exp(valid_loss):7.3f}')

# %%
# for cpu usage
# model.load_state_dict(torch.load(MODEL_NAME, map_location=torch.device('cpu')))

# for gpu usage
model.load_state_dict(torch.load(MODEL_NAME))
model.to(device)


test_loss = evaluate(model, valid_iterator, criterion)

print(f'| Test Loss: {test_loss:.3f} | Test PPL: {math.exp(test_loss):7.3f} |')
# Out:
# | Test Loss: 5.427 | Test PPL: 227.420 |

# %%
MODEL_NAME = 'cache/best_model_dict_gru_gru2.pt'
torch.save(model.state_dict(), MODEL_NAME)

# %% [markdown]
# ### Генерация заголовков

# %%
def beam_search(data, k, eos_idx):
    data -= data.min()
    data /= data.max()
    best_indexes = data[0].sort(dim=0, descending=True).indices[:3].tolist()
    sequences = [[[index], score if score != 0 else 0.0001] for index, score in zip(best_indexes, data[0][best_indexes].tolist())]
    # print(sequences)
    # walk over each step in sequence
    for row in data[1:]:
        all_candidates = sequences.copy()
        # expand each current candidate
        for i in range(len(sequences)):
            seq, score = sequences[i]
            if seq[-1] != eos_idx: 
                for j in range(len(row)):
                    delta = row[j].item() if row[j].item() != 0 else 0.0001
                    candidate = [seq + [j], (score * delta)**(1/(len(seq)+1)) ]
                    all_candidates.append(candidate)
        # order all candidates by score
        # print(all_candidates)
        ordered = sorted(all_candidates, key=lambda tup:tup[1], reverse=True)
        # select k best
        sequences = ordered[:k]
    return sequences[0][0]

# %%
def translate_sentence(model, tokenized_sentence):
    model.eval()
    tokenized_sentence = ['<sos>'] + [t.lower() for t in tokenized_sentence] + ['<eos>']
    numericalized = [TEXT.vocab.stoi[t] for t in tokenized_sentence] 
    sentence_length = torch.LongTensor([len(numericalized)]).to(device) 
    tensor = torch.LongTensor(numericalized).unsqueeze(1).to(device) 
    translation_tensor_logits, attention = model(tensor, sentence_length, None, 0)
    # translation_tensor = beam_search(translation_tensor_logits.squeeze(1), 5, model.eos_idx)
    translation_tensor = torch.argmax(translation_tensor_logits.squeeze(1), 1)
    translation = [TEXT.vocab.itos[t] for t in translation_tensor]
    translation, attention = translation[1:], attention[1:]
    return translation, attention

# %%
def display_attention(sentence, translation, attention):
    
    fig = plt.figure(figsize=(30,50))
    ax = fig.add_subplot(111)
    
    attention = attention.squeeze(1).cpu().detach().numpy().T
    
    cax = ax.matshow(attention, cmap='bone')
   
    ax.tick_params(labelsize=12)
    ax.set_yticklabels(['']+['<sos>']+[t.lower() for t in sentence]+['<eos>'])
    ax.set_xticklabels(['']+translation, rotation=80)

    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

    plt.show()
    plt.close()

# %%
example_idx = 100

src = vars(train_data.examples[example_idx])['src']
trg = vars(train_data.examples[example_idx])['trg']

print(f'src = {src}')
print(f'trg = {trg}')
# Out:
# src = ['the', 'integrated', 'completed', 'likelihood', '(', 'icl', ')', 'criterion', 'has', 'proven', 'to', 'be', 'a', 'very', 'popular', 'approach', 'in', 'model', '-', 'based', 'clustering', 'through', 'automatically', 'choosing', 'the', 'number', 'of', 'clusters', 'in', 'a', 'mixture', 'model', '.', 'this', 'approach', 'effectively', 'maximises', 'the', 'complete', 'data', 'likelihood', ',', 'thereby', 'including', 'the', 'allocation', 'of', 'observations', 'to', 'clusters', 'in', 'the', 'model', 'selection', 'criterion', '.', 'however', 'for', 'practical', 'implementation', 'one', 'needs', 'to', 'introduce', 'an', 'approximation', 'in', 'order', 'to', 'estimate', 'the', 'icl', '.', 'our', 'contribution', 'here', 'is', 'to', 'illustrate', 'that', 'through', 'the', 'use', 'of', 'conjugate', 'priors', 'one', 'can', 'derive', 'an', 'exact', 'expression', 'for', 'icl', 'and', 'so', 'avoiding', 'any', 'approximation', '.', 'moreover', ',', 'we', 'illustrate', 'how', 'one', 'can', 'find', 'both', 'the', 'number', 'of', 'clusters', 'and', 'the', 'best', 'allocation', 'of', 'observations', 'in', 'one', 'algorithmic', 'framework', '.', 'the', 'performance', 'of', 'our', 'algorithm', 'is', 'presented', 'on', 'several', 'simulated', 'and', 'real', 'examples', '.']
# trg = ['choosing', 'the', 'number', 'of', 'clusters', 'in', 'a', 'finite', 'mixture', 'model', 'using', 'an', 'exact', 'integrated', 'completed', 'likelihood', 'criterion']

# %%
translation, attention = translate_sentence(model, src)

print(f'predicted trg = {translation}')
# Out:
# predicted trg = ['moments', 'of', 'moments', 'of', 'moments', 'of', 'graph', 'models']

# %%
display_attention(src, translation, attention)

# %%
for example_idx in range(100, 1000):
    src = vars(train_data.examples[example_idx])['src']
    trg = vars(train_data.examples[example_idx])['trg']
    translation, attention = translate_sentence(model, src)

    print('Оригинальный заголовок: ', ' '.join(trg))
    print('Предсказанный заголовок: ', ' '.join(translation))
    print('-----------------------------------')
# Out:
# Оригинальный заголовок:  choosing the number of clusters in a finite mixture model using an exact integrated completed likelihood criterion
# Предсказанный заголовок:  a likelihood clustering for clusters in clusters
# -----------------------------------
# Оригинальный заголовок:  learning hybrid sparsity prior for image restoration : where deep learning meets sparse coding
# Предсказанный заголовок:  hybrid hybrid coding for hybrid hybrid coding
# -----------------------------------
# Оригинальный заголовок:  explaining temporal trends in annualized relapse rates in placebo groups of randomized controlled trials in relapsing multiple sclerosis : systematic review and meta - regression
# Предсказанный заголовок:  annualized relapse rates annualized placebo placebo placebo placebo placebo placebo placebo placebo placebo trials placebo relapsing trials
# -----------------------------------
# Оригинальный заголовок:  the bounds of heavy - tailed return distributions in evolving complex networks
# Предсказанный заголовок:  the degree distribution of growing networks
# -----------------------------------
# Оригинальный заголовок:  the constrained maximum likelihood estimation for parameters arising from partially identified models
# Предсказанный заголовок:  constrained maximum likelihood estimation constrained estimation models
# -----------------------------------
# Оригинальный заголовок:  taibleson operators , p - adic parabolic equations and ultrametric diffusion
# Предсказанный заголовок:  on the p - adic equation equation
# -----------------------------------
# Оригинальный заголовок:  bayesdccgarch - an implementation of multivariate garch dcc models
# Предсказанный заголовок:  garch models dcc garch dcc dcc models dcc models dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc dcc
# -----------------------------------
# Оригинальный заголовок:  tiling solutions for optimal biological sensing
# Предсказанный заголовок:  the of of of gene regulatory networks
# -----------------------------------
# Оригинальный заголовок:  a knockoff filter for high - dimensional selective inference
# Предсказанный заголовок:  knockoff knockoff discovery in knockoff - dimensional linear models
# -----------------------------------
# Оригинальный заголовок:  natural topologies on colombeau algebras
# Предсказанный заголовок:  on of of algebra of colombeau algebras
# -----------------------------------
# Оригинальный заголовок:  introduction to papers on astrostatistics
# Предсказанный заголовок:  some overview of the astrostatistics : the review
# -----------------------------------
# Оригинальный заголовок:  a consistent multi - user framework for assessing system performance
# Предсказанный заголовок:  a review of <unk> - based reasoning in multiple systems
# -----------------------------------
# Оригинальный заголовок:  a review of audio features and statistical models exploited for voice pattern design
# Предсказанный заголовок:  audio audio exploited audio audio audio audio exploited audio audio exploited exploited audio audio exploited
# -----------------------------------
# Оригинальный заголовок:  study of the decay mechanism for b+ to p pbar k+ and b+ to p pbar pi+
# Предсказанный заголовок:  branching fraction of b+ b+ b+ b+ b+ b+ b+ b+ decays b+ - > k+ b+ - > k+
# -----------------------------------
# Оригинальный заголовок:  the method of moments and degree distributions for network models
# Предсказанный заголовок:  moments of moments of moments of graph models
# -----------------------------------
# Оригинальный заголовок:  hypothesis testing near singularities and boundaries
# Предсказанный заголовок:  on the likelihood likelihood likelihood likelihood for the mean mean mean
# -----------------------------------
# Оригинальный заголовок:  smered : a bayesian approach to graphical record linkage and de - duplication
# Предсказанный заголовок:  unsupervised record linkage for record linkage linkage
# -----------------------------------
# Оригинальный заголовок:  deep - learning - based breast ct for radiation dose reduction
# Предсказанный заголовок:  deep - dose ct dose ct dose ct dose ct dose ct images
# -----------------------------------
# Оригинальный заголовок:  rodeo : sparse , greedy nonparametric regression
# Предсказанный заголовок:  rodeo : rodeo : greedy rodeo
# -----------------------------------
# Оригинальный заголовок:  ionized and neutral gas in the peculiar star / cluster complex in ngc 6946
# Предсказанный заголовок:  the the of of the of ngc <unk> ngc <unk>
# -----------------------------------
# Оригинальный заголовок:  random walks in random environments
# Предсказанный заголовок:  random walks in random random walk
# -----------------------------------
# Оригинальный заголовок:  optimal resource diffusion for suppressing disease spreading in multiplex networks
# Предсказанный заголовок:  epidemic spreading in a diffusion networks
# -----------------------------------
# Оригинальный заголовок:  exponential sums and rank of persymmetric matrices over f_2
# Предсказанный заголовок:  on the of persymmetric matrices persymmetric matrices
# -----------------------------------
# Оригинальный заголовок:  optimized routing and spectrum assignment for video communication over an elastic optical network
# Предсказанный заголовок:  deep learning for optical communication networks
# -----------------------------------
# Оригинальный заголовок:  correlated random walks and the joint survival probability
# Предсказанный заголовок:  credit default swaps and default risk
# -----------------------------------
# Оригинальный заголовок:  interpretable deep neural networks for single - trial eeg classification
# Предсказанный заголовок:  deep neural networks : interpretable neural networks
# -----------------------------------
# Оригинальный заголовок:  bivariate linear mixed models using sas proc mixed
# Предсказанный заголовок:  bivariate mixed mixed sas sas proc proc mixed sas proc mixed models
# -----------------------------------
# Оригинальный заголовок:  $ l^\gamma$-pagerank for semi - supervised learning
# Предсказанный заголовок:  graph - supervised learning graph classification
# -----------------------------------
# Оригинальный заголовок:  limits on wimp - nucleon interactions with csi(tl ) crystal detectors
# Предсказанный заголовок:  wimp - of the - nucleon scattering
# -----------------------------------
# Оригинальный заголовок:  front - like entire solutions for monostable reaction - diffusion systems
# Предсказанный заголовок:  cooperative solutions of cooperative cooperative monostable cooperative cooperative systems
# -----------------------------------
# Оригинальный заголовок:  micro - randomized trials in mhealth
# Предсказанный заголовок:  randomization - trials : personalized randomization - trials
# -----------------------------------
# Оригинальный заголовок:  modelling the atp production in mitochondria
# Предсказанный заголовок:  modeling of the of of the of of the <unk>
# -----------------------------------
# Оригинальный заголовок:  likelihood analysis for a class of spatial geostatistical compositional models
# Предсказанный заголовок:  a - - geostatistical models for geostatistical models
# -----------------------------------
# Оригинальный заголовок:  connected components of strata of quadratic differentials over teichmuller space
# Предсказанный заголовок:  on of of differentials on the differentials on the differentials
# -----------------------------------
# Оригинальный заголовок:  tunneling spectroscopy of persistent currents in superconducting microrings
# Предсказанный заголовок:  superconducting conductance of conductance in superconducting superconductor - superconductor - superconductor
# -----------------------------------
# Оригинальный заголовок:  allowance prices in the eu ets -- fundamental price drivers and the recent upward trend
# Предсказанный заголовок:  allowance price of the price in the markets
# -----------------------------------
# Оригинальный заголовок:  bgg correspondence for toric complete intersections
# Предсказанный заголовок:  bernstein bernstein - toric toric varieties toric toric varieties toric toric varieties
# -----------------------------------
# Оригинальный заголовок:  approximate unitary equivalence in simple c^*-algebras of tracial rank one
# Предсказанный заголовок:  c*-algebras of c*-algebras c*-algebras c*-algebras c*-algebras c*-algebras c*-algebras c*-algebras
# -----------------------------------
# Оригинальный заголовок:  simulating organogenesis : algorithms for the image - based determination of displacement fields
# Предсказанный заголовок:  3d organogenesis in organogenesis in 3d image reconstruction
# -----------------------------------
# Оригинальный заголовок:  sample complexity analysis for learning overcomplete latent variable models through tensor methods
# Предсказанный заголовок:  learning learning overcomplete overcomplete overcomplete latent models
# -----------------------------------
# Оригинальный заголовок:  multiscale edge detection and parametric shape modeling for boundary delineation in optoacoustic images
# Предсказанный заголовок:  multiscale image segmentation for optoacoustic tomography
# -----------------------------------
# Оригинальный заголовок:  codeword stabilized quantum codes
# Предсказанный заголовок:  codeword error codes for quantum codes codes
# -----------------------------------
# Оригинальный заголовок:  deriving chemosensitivity from cell lines : forensic bioinformatics and reproducible research in high - throughput biology
# Предсказанный заголовок:  reproducible research in pediatric primary healthcare : a reproducible research
# -----------------------------------
# Оригинальный заголовок:  first law of black saturn thermodynamics
# Предсказанный заголовок:  black black holes black holes black holes
# -----------------------------------
# Оригинальный заголовок:  piece - wise quadratic approximations of arbitrary error functions for fast and robust machine learning
# Предсказанный заголовок:  approximation methods for regularized kernels
# -----------------------------------
# Оригинальный заголовок:  brainstorming : consensus learning in practice
# Предсказанный заголовок:  consensus : consensus consensus consensus
# -----------------------------------
# Оригинальный заголовок:  strange non - chaotic attractors in quasiperiodically forced circle maps
# Предсказанный заголовок:  chaotic attractors attractors attractors in quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced quasiperiodically forced
# -----------------------------------
# Оригинальный заголовок:  diophantine undecidability of holomorphy rings of function fields of characteristic 0
# Предсказанный заголовок:  on of of of p - fields
# -----------------------------------
# Оригинальный заголовок:  asymptotic properties of hilbert geometry
# Предсказанный заголовок:  the differentiability of differentiability of lorentzian metrics on the sphere
# -----------------------------------
# Оригинальный заголовок:  margin setting with high - frequency data1
# Предсказанный заголовок:  margin impact of stock price impact
# -----------------------------------
# Оригинальный заголовок:  dissipation of magnetic flux in primordial star formation : from run - away phase to mass accretion phase
# Предсказанный заголовок:  magnetic field in the magnetic field in the disk
# -----------------------------------
# Оригинальный заголовок:  on the 5d extra - force according to basini - capozziello - ponce de leon formalism and the experimental research of extra dimensions on - board international space station(iss ) using laser beams
# Предсказанный заголовок:  the deflection of the earth 's
# -----------------------------------
# Оригинальный заголовок:  derivation of arch(1 ) process from market price changes based on deterministic microscopic multi - agent
# Предсказанный заголовок:  the price dynamics in the price model
# -----------------------------------
# Оригинальный заголовок:  deterministic conditions for subspace identifiability from incomplete sampling
# Предсказанный заголовок:  subspace subspace identifiability of subspace identifiability
# -----------------------------------
# Оригинальный заголовок:  genetic algorithm for constrained optimization with stochastic feasibility region with application to vehicle path planning
# Предсказанный заголовок:  a path algorithm for path - tracking
# -----------------------------------
# Оригинальный заголовок:  coding on countably infinite alphabets
# Предсказанный заголовок:  coding countably countably alphabets alphabets alphabets alphabets
# -----------------------------------
# Оригинальный заголовок:  branching processes in random environment die slowly
# Предсказанный заголовок:  on the limit theorem for the random of the random walk
# -----------------------------------
# Оригинальный заголовок:  sensing tensors with gaussian filters
# Предсказанный заголовок:  sparse sparse recovery of sparse sparse recovery
# -----------------------------------
# Оригинальный заголовок:  extreme values for benedicks - carleson quadratic maps
# Предсказанный заголовок:  benedicks - carleson benedicks benedicks carleson benedicks benedicks carleson benedicks benedicks carleson carleson benedicks benedicks carleson carleson benedicks benedicks carleson carleson
# -----------------------------------
# Оригинальный заголовок:  cryptogauge symmetry and cryptoghosts for crypto - hermitian hamiltonians
# Предсказанный заголовок:  hamiltonian crypto - hermitian oscillator
# -----------------------------------
# Оригинальный заголовок:  spectral geometry , homogeneous spaces , and differential forms with finite fourier series
# Предсказанный заголовок:  harmonic harmonic actions on compact lie groups
# -----------------------------------
# Оригинальный заголовок:  a conversation with monroe sirken
# Предсказанный заголовок:  conversation with conversation with monroe <unk> conversation with conversation with conversation with conversation with r. <unk>
# -----------------------------------
# Оригинальный заголовок:  q - valued functions revisited
# Предсказанный заголовок:  on the of of the functions
# -----------------------------------
# Оригинальный заголовок:  lipschitz parametrization of probabilistic graphical models
# Предсказанный заголовок:  on the kullback - leibler divergence
# -----------------------------------
# Оригинальный заголовок:  simple estimators of false discovery rates given as few as one or two p - values without strong parametric assumptions
# Предсказанный заголовок:  on false discovery rates for false discovery rate
# -----------------------------------
# Оригинальный заголовок:  long range order for lattice dipoles
# Предсказанный заголовок:  spin spin of the heisenberg spin chains
# -----------------------------------
# Оригинальный заголовок:  variational scheme to compute protein reaction pathways using atomistic force fields with explicit solvent
# Предсказанный заголовок:  variational coarse graining of molecular dynamics of molecular dynamics
# -----------------------------------
# Оригинальный заголовок:  elation generalised quadrangles of order ( s , p ) , where p is prime
# Предсказанный заголовок:  a <unk> <unk> <unk> <unk> <unk> <unk>
# -----------------------------------
# Оригинальный заголовок:  background subtraction via fast robust matrix completion
# Предсказанный заголовок:  robust - completion : low - rank matrix completion
# -----------------------------------
# Оригинальный заголовок:  glasses : relieving the myopia of bayesian optimisation
# Предсказанный заголовок:  glasses : relieving myopia myopia myopia
# -----------------------------------
# Оригинальный заголовок:  beyond network structure : how heterogenous susceptibility modulates the spread of epidemics
# Предсказанный заголовок:  epidemic spreading in epidemic epidemic epidemic epidemic model
# -----------------------------------
# Оригинальный заголовок:  co - existence of micro , pico and atto cells in optical wireless communication
# Предсказанный заголовок:  cell cell cell cell pico in pico pico
# -----------------------------------
# Оригинальный заголовок:  is there currently a scientific revolution in scientometrics ?
# Предсказанный заголовок:  is there currently currently currently scientometrics ? scientometrics ? scientometrics ?
# -----------------------------------
# Оригинальный заголовок:  interpretation of the arithmetic in certain groups of piecewise affine permutations of an interval
# Предсказанный заголовок:  thompson 's groups of thompson groups
# -----------------------------------
# Оригинальный заголовок:  time for a change : a tutorial for comparing multiple classifiers through bayesian analysis
# Предсказанный заголовок:  a tutorial on the learning of
# -----------------------------------
# Оригинальный заголовок:  incompleteness of the bond market with l\'evy noise under the physical measure
# Предсказанный заголовок:  the the of the of the market market model
# -----------------------------------
# Оригинальный заголовок:  fast deep learning for automatic modulation classification
# Предсказанный заголовок:  deep fried classification for convolutional neural networks
# -----------------------------------
# Оригинальный заголовок:  orbital stability of traveling waves for the one - dimensional gross - pitaevskii equation
# Предсказанный заголовок:  stability stability of the gross - pitaevskii equation
# -----------------------------------
# Оригинальный заголовок:  epidemics in markets with trade friction and imperfect transactions
# Предсказанный заголовок:  heterogeneous trade - agent - in a - agent -
# -----------------------------------
# Оригинальный заголовок:  desingularization of g_2 manifolds with isolated conical singularities
# Предсказанный заголовок:  on manifolds g_2 manifolds
# -----------------------------------
# Оригинальный заголовок:  developing ecospheres on transiently habitable planets : the genesis project
# Предсказанный заголовок:  darwin habitable habitable habitable habitable habitable habitable habitable
# -----------------------------------
# Оригинальный заголовок:  on the image of code polynomials under theta map
# Предсказанный заголовок:  the of of of the varieties
# -----------------------------------
# Оригинальный заголовок:  failure and uses of jaynes ' principle of transformation groups
# Предсказанный заголовок:  jaynes - uses jaynes jaynes jaynes jaynes uses
# -----------------------------------
# Оригинальный заголовок:  on the rate of convergence of periodic solutions in perturbed autonomous systems as the perturbation vanishes
# Предсказанный заголовок:  periodic solutions of the autonomous system
# -----------------------------------
# Оригинальный заголовок:  reducing offline evaluation bias in recommendation systems
# Предсказанный заголовок:  offline offline evaluation of recommendation recommendation offline evaluation
# -----------------------------------
# Оригинальный заголовок:  automatic trading agent . rmt based portfolio theory and portfolio selection
# Предсказанный заголовок:  making of portfolio portfolio
# -----------------------------------
# Оригинальный заголовок:  arbitrary precision composite pulses for nmr quantum computing
# Предсказанный заголовок:  double - of pulses for double pulses
# -----------------------------------
# Оригинальный заголовок:  certain aperiodic automorphisms of unital simple projectionless c*-algebras
# Предсказанный заголовок:  c*-algebras of c*-algebras of c*-algebras c*-algebras c*-algebras
# -----------------------------------
# Оригинальный заголовок:  correlation breakdown , copula credit default models and arbitrage
# Предсказанный заголовок:  credit default swaps in credit default
# -----------------------------------
# Оригинальный заголовок:  exponential decay of correlation for the stochastic process associated to the entropy penalized method
# Предсказанный заголовок:  on the of of the correlation of the stochastic correlation
# -----------------------------------
# Оригинальный заголовок:  audio - based music classification with densenet and data augmentation
# Предсказанный заголовок:  audio music classification for music music convolutional neural networks
# -----------------------------------
# Оригинальный заголовок:  direct bootstrapping and permuting of observations fail for aalen - johansen estimators
# Предсказанный заголовок:  bootstrapping bootstrapping bootstrap aalen johansen aalen johansen aalen aalen aalen johansen johansen processes aalen aalen johansen johansen processes
# -----------------------------------
# Оригинальный заголовок:  saturation probabilities of continuous - time sigmoidal networks
# Предсказанный заголовок:  a - valued networks networks networks
# -----------------------------------
# Оригинальный заголовок:  modeling of the multiwavelength emission of m87 with h.e.s.s . observations
# Предсказанный заголовок:  tev m87 of m87 blazars
# -----------------------------------
# Оригинальный заголовок:  on the difference between solutions of discrete tomography problems
# Предсказанный заголовок:  reconstruction of the projections of the projections
# -----------------------------------
# Оригинальный заголовок:  shape theory via polar decomposition
# Предсказанный заголовок:  shape shape shape shape shape shape shape shape
# -----------------------------------
# Оригинальный заголовок:  discovery of two candidate pulsar wind nebulae in very - high - energy gamma rays
# Предсказанный заголовок:  search for hess pwn pulsar wind nebula hess hess hess hess hess j1718 nebula hess hess j1718 nebula hess hess j1718 - hess j1718 - hess j1718 - hess j1718 - hess j1718 - hess j1718 - hess j1718 - hess j1718 - hess j1718 - hess j1718 - hess j1718 - hess j1718 - hess j1718 - hess j1718 - hess j1718 - hess j1718 - hess j1718 - hess j1718 - hess j1718 - hess j1718 - hess j1718 - hess j1718 - hess j1718 - hess j1718 - hess j1718 - hess j1718 - hess j1718
# -----------------------------------
# Оригинальный заголовок:  a tail sensitive test for cumulative distribution functions
# Предсказанный заголовок:  testing of a distribution of a distribution of distribution
# -----------------------------------
# Оригинальный заголовок:  the quandle of the trefoil knot as the dehn quandle of the torus
# Предсказанный заголовок:  dehn dehn dehn dehn dehn dehn dehn dehn
# -----------------------------------
# Оригинальный заголовок:  constructive $ \phi^4 $ field theory without tears
# Предсказанный заголовок:  \phi^4 \phi^4 \phi^4 \phi^4 \phi^4 \phi^4 \phi^4 \phi^4 \phi^4 \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $ \phi^4 $
# -----------------------------------
# Оригинальный заголовок:  empirical transverse charge densities in the nucleon and the nucleon - to-$\delta$ transition
# Предсказанный заголовок:  density of density densities in the nucleon density
# -----------------------------------
# Оригинальный заголовок:  the international linear collider
# Предсказанный заголовок:  ilc : ilc ilc
# -----------------------------------
# Оригинальный заголовок:  conformal structures in noncommutative geometry
# Предсказанный заголовок:  dirac operators on the heisenberg lie
# -----------------------------------
# Оригинальный заголовок:  statistical mechanics for natural flocks of birds
# Предсказанный заголовок:  statistical mechanics of birds flocks flocks
# -----------------------------------
# Оригинальный заголовок:  meeting yield and conservation objectives by balancing harvesting of juveniles and adults
# Предсказанный заголовок:  the harvesting harvesting policy : policy - policy policy
# -----------------------------------
# Оригинальный заголовок:  parametric estimation and tests through divergences and duality technique
# Предсказанный заголовок:  divergences and divergences tests for divergences
# -----------------------------------
# Оригинальный заголовок:  heterogeneous inputs to central pattern generators can shape insect gaits
# Предсказанный заголовок:  a of of locomotion of rhythmic locomotion
# -----------------------------------
# Оригинальный заголовок:  estimating nonlinear regression errors without doing regression
# Предсказанный заголовок:  nonlinear nonlinear regression doing regression doing doing regression regression
# -----------------------------------
# Оригинальный заголовок:  reconstruction of the external stimuli from brain signals
# Предсказанный заголовок:  eeg - based brain - computer interfaces
# -----------------------------------
# Оригинальный заголовок:  stroke controllable fast style transfer with adaptive receptive fields
# Предсказанный заголовок:  adversarial style transfer for stroke style transfer
# -----------------------------------
# Оригинальный заголовок:  distance maps and plant development # 2 : facilitated transport and uniform gradient
# Предсказанный заголовок:  the of of of of cells
# -----------------------------------
# Оригинальный заголовок:  symmetry breaking in few layer graphene films
# Предсказанный заголовок:  the - of the - - band - in the - doped manganites
# -----------------------------------
# Оригинальный заголовок:  targeted source detection for environmental data
# Предсказанный заголовок:  identification of signal detection in environmental environmental and environmental signal
# -----------------------------------
# Оригинальный заголовок:  bayesian design of experiments using approximate coordinate exchange
# Предсказанный заголовок:  bayesian design for bayesian - - models
# -----------------------------------
# Оригинальный заголовок:  schur positivity and the $ q$-log - convexity of the narayana polynomials
# Предсказанный заголовок:  schur narayana polynomials schur schur narayana polynomials
# -----------------------------------
# Оригинальный заголовок:  on orbits of the ring $ z_n^m$ under the action of the group $ sl(m , z_n)$
# Предсказанный заголовок:  orbits of orbits of finite orbits of z_n)$
# -----------------------------------
# Оригинальный заголовок:  analytic crossing probabilities for certain barriers by brownian motion
# Предсказанный заголовок:  crossing crossing crossing probabilities for crossing barriers
# -----------------------------------
# Оригинальный заголовок:  on particle gibbs sampling
# Предсказанный заголовок:  gibbs gibbs gibbs gibbs gibbs gibbs gibbs gibbs gibbs gibbs gibbs gibbs gibbs gibbs gibbs gibbs gibbs gibbs gibbs sampling
# -----------------------------------
# Оригинальный заголовок:  wolbachia infection in a sex - structured mosquito population carrying west nile virus
# Предсказанный заголовок:  wolbachia - wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia wolbachia
# -----------------------------------
# Оригинальный заголовок:  birational mappings and matrix sub - algebra from the chiral potts model
# Предсказанный заголовок:  birational potts models of potts models
# -----------------------------------
# Оригинальный заголовок:  measuring value in healthcare
# Предсказанный заголовок:  hitting times in healthcare : a healthcare : a case study of health outcomes
# -----------------------------------
# Оригинальный заголовок:  on generalized estimating equations for vector regression
# Предсказанный заголовок:  generalized generalized generalized gee analysis for longitudinal data
# -----------------------------------
# Оригинальный заголовок:  robust logitboost and adaptive base class ( abc ) logitboost
# Предсказанный заголовок:  logitboost logitboost logitboost logitboost logitboost logitboost logitboost logitboost logitboost logitboost logitboost logitboost logitboost logitboost logitboost logitboost logitboost logitboost
# -----------------------------------
# Оригинальный заголовок:  point process modeling for directed interaction networks
# Предсказанный заголовок:  a of of of of of boolean networks
# -----------------------------------
# Оригинальный заголовок:  wavelet algorithm for the identification of p300 erp component
# Предсказанный заголовок:  computer p300 p300 bci p300 p300 bci p300 p300 bci p300 p300 bci
# -----------------------------------
# Оригинальный заголовок:  conjugacy of p - configurations and nonlinear solutions to a certain conditional cauchy equation
# Предсказанный заголовок:  on the solutions of solutions of functional equations
# -----------------------------------
# Оригинальный заголовок:  a strong test of the maximum entropy theory of ecology
# Предсказанный заголовок:  the the of of species
# -----------------------------------
# Оригинальный заголовок:  collaborative ensemble learning : combining collaborative and content - based information filtering via hierarchical bayes
# Предсказанный заголовок:  collaborative ensemble learning for collaborative collaborative filtering
# -----------------------------------
# Оригинальный заголовок:  casimir forces in a t operator approach
# Предсказанный заголовок:  casimir casimir forces in the casimir casimir forces
# -----------------------------------
# Оригинальный заголовок:  improving the asymptotic performance of markov chain monte - carlo by inserting vortices
# Предсказанный заголовок:  markov chain monte carlo samplers inserting reversible markov chains
# -----------------------------------
# Оригинальный заголовок:  using multiple samples to learn mixture models
# Предсказанный заголовок:  a em em for mixture models
# -----------------------------------
# Оригинальный заголовок:  linear non - gaussian component analysis via maximum likelihood
# Предсказанный заголовок:  component component analysis component analysis
# -----------------------------------
# Оригинальный заголовок:  isicle : a molecular collision cross section calculation pipeline for establishing large in silico reference libraries for compound identification
# Предсказанный заголовок:  <unk> : a python package for the biology
# -----------------------------------
# Оригинальный заголовок:  effects of the disconnected flavor singlet corrections on the hyperfine splitting in charmonium
# Предсказанный заголовок:  flavor flavor flavor flavor flavor flavor flavor flavor flavor flavor flavor
# -----------------------------------
# Оригинальный заголовок:  secular bipolar growth rate of the real us gdp per capita : implications for understanding past and future economic growth
# Предсказанный заголовок:  gdp growth of growth growth growth
# -----------------------------------
# Оригинальный заголовок:  on a possible interpretation of fusion in stochastic loewner evolution
# Предсказанный заголовок:  loewner loewner loewner evolution
# -----------------------------------
# Оригинальный заголовок:  graphical lasso based model selection for time series
# Предсказанный заголовок:  graphical selection for stationary time series
# -----------------------------------
# Оригинальный заголовок:  bootstrap - based model selection criteria for beta regressions
# Предсказанный заголовок:  penalized selection selection criterion for penalized selection selection
# -----------------------------------
# Оригинальный заголовок:  destructed double - layer and ionic charge separation near the oil - water interface
# Предсказанный заголовок:  ionic solvation ionic oil oil oil oil oil oil oil oil oil oil oil oil oil oil oil oil oil oil oil oil oil oil oil oil oil oil oil oil
# -----------------------------------
# Оригинальный заголовок:  a multilevel framework for sparse optimization with application to inverse covariance estimation and logistic regression
# Предсказанный заголовок:  l1 regularization for sparse regularized least squares
# -----------------------------------
# Оригинальный заголовок:  unitary solution to a quantum gravity information paradox
# Предсказанный заголовок:  the - of the - - time -
# -----------------------------------
# Оригинальный заголовок:  the intersection of a curve with a union of translated codimension 2 subgroups in a power of an elliptic curve
# Предсказанный заголовок:  on of of curves of elliptic curves
# -----------------------------------
# Оригинальный заголовок:  operator methods , abelian processes and dynamic conditioning
# Предсказанный заголовок:  a - - - - - - - - - -
# -----------------------------------
# Оригинальный заголовок:  lung ultrasound surface wave elastography for assessing instititial lung disease
# Предсказанный заголовок:  lung lung elastography lung tongue lung lung lung lung lung lung lung lung lung lung lung lung lung lung lung lung lung lung lung lung lung
# -----------------------------------
# Оригинальный заголовок:  mean - variance asset - liability management with state - dependent risk aversion
# Предсказанный заголовок:  optimal - - mean - variance hedging under mean - variance
# -----------------------------------
# Оригинальный заголовок:  reduction algorithm for the npmle for the distribution function of bivariate interval censored data
# Предсказанный заголовок:  efficient computation of the npmle censoring bivariate censored censoring
# -----------------------------------
# Оригинальный заголовок:  on energy harvesting of hybrid tdma - noma systems
# Предсказанный заголовок:  energy - noma noma noma noma noma noma noma noma
# -----------------------------------
# Оригинальный заголовок:  privacy and statistical risk : formalisms and minimax bounds
# Предсказанный заголовок:  privacy privacy privacy privacy
# -----------------------------------
# Оригинальный заголовок:  robust estimation in generalised linear models : the density power divergence approach
# Предсказанный заголовок:  robust robust linear models models
# -----------------------------------
# Оригинальный заголовок:  mean field limit for bosons and infinite dimensional phase - space analysis
# Предсказанный заголовок:  on of of field field field field field field field field field field field field field field field field field field field field field field field field field
# -----------------------------------
# Оригинальный заголовок:  universality and diversity of folding mechanics for three - helix bundle proteins
# Предсказанный заголовок:  folding folding folding folding folding folding folding
# -----------------------------------
# Оригинальный заголовок:  classification based on a permanental process with cyclic approximation
# Предсказанный заголовок:  classification of cox process
# -----------------------------------
# Оригинальный заголовок:  maximum likelihood drift estimation for the mixing of two fractional brownian motions
# Предсказанный заголовок:  maximum likelihood estimation of the drift of fractional brownian motions
# -----------------------------------
# Оригинальный заголовок:  long term economic relationships from cointegration maps
# Предсказанный заголовок:  a bayesian of of bayesian data
# -----------------------------------
# Оригинальный заголовок:  codimension two bifurcations and rythms in neural mass models
# Предсказанный заголовок:  the of of of the of of seizures
# -----------------------------------
# Оригинальный заголовок:  likelihood - free simulation - based optimal design
# Предсказанный заголовок:  a - optimal designs for optimal design
# -----------------------------------
# Оригинальный заголовок:  automatic matching of bullet land impressions
# Предсказанный заголовок:  bullet impressions impressions impressions impressions impressions impressions impressions impressions
# -----------------------------------
# Оригинальный заголовок:  low - rank modeling and its applications in image analysis
# Предсказанный заголовок:  low rank rank rank rank rank rank rank rank rank models
# -----------------------------------
# Оригинальный заголовок:  the scale invariant wigner spectrum estimation of gaussian locally self - similar processes
# Предсказанный заголовок:  self self - similar self - similar self - similar processes
# -----------------------------------
# Оригинальный заголовок:  intermediated implementation
# Предсказанный заголовок:  intermediated by : a : a
# -----------------------------------
# Оригинальный заголовок:  inference of cancer progression models with biological noise
# Предсказанный заголовок:  inferring cancer progression progression progression
# -----------------------------------
# Оригинальный заголовок:  flexible online repeated measures experiment
# Предсказанный заголовок:  online online online for online in significant streams
# -----------------------------------
# Оригинальный заголовок:  tyler 's covariance matrix estimator in elliptical models with convex structure
# Предсказанный заголовок:  tyler 's covariance estimation for elliptical covariance estimation
# -----------------------------------
# Оригинальный заголовок:  a stochastic analysis of table tennis
# Предсказанный заголовок:  on the of the tennis
# -----------------------------------
# Оригинальный заголовок:  uniform observability of hidden markov models and filter stability for unstable signals
# Предсказанный заголовок:  stability of stability of stability of nonlinear filters
# -----------------------------------
# Оригинальный заголовок:  quantum transport on small - world networks : a continuous - time quantum walk approach
# Предсказанный заголовок:  quantum transport in quantum transport in a quantum -
# -----------------------------------
# Оригинальный заголовок:  emergence of correlations between securities at short time scales
# Предсказанный заголовок:  correlation correlation correlation correlation correlation in the correlation matrix
# -----------------------------------
# Оригинальный заголовок:  optimal variable selection in multi - group sparse discriminant analysis
# Предсказанный заголовок:  group - group multi - group multi - group group
# -----------------------------------
# Оригинальный заголовок:  estimating player contribution in hockey with regularized logistic regression
# Предсказанный заголовок:  a regression regression for hockey
# -----------------------------------
# Оригинальный заголовок:  analysis of the spread of tuberculosis in heterogeneous complex metapopulations
# Предсказанный заголовок:  epidemic - of metapopulations in metapopulations
# -----------------------------------
# Оригинальный заголовок:  opening discussion on banking sector risk exposures and vulnerabilities from virtual currencies : an operational risk perspective
# Предсказанный заголовок:  banking risk and banking risk
# -----------------------------------
# Оригинальный заголовок:  coupling of surface and volume dipole oscillations in c-60 molecules
# Предсказанный заголовок:  quantum - of the in a quantum -
# -----------------------------------
# Оригинальный заголовок:  on debiasing restoration algorithms : applications to total - variation and nonlocal - means
# Предсказанный заголовок:  comment debiasing restoration : a bias reduction
# -----------------------------------
# Оригинальный заголовок:  macrostate parameter and investment risk diagrams for 2008 and 2009
# Предсказанный заголовок:  macrostate risk in the risk : a case of the risk
# -----------------------------------
# Оригинальный заголовок:  mutant knots with symmetry
# Предсказанный заголовок:  knot knots and knot invariants
# -----------------------------------
# Оригинальный заголовок:  analogue of superradiance effect in acoustic black hole in the presence of disclination
# Предсказанный заголовок:  acoustic acoustic acoustic acoustic acoustic model
# -----------------------------------
# Оригинальный заголовок:  inductive analysis on singular minimal hypersurfaces
# Предсказанный заголовок:  on hypersurfaces of hypersurfaces hypersurfaces
# -----------------------------------
# Оригинальный заголовок:  gauge symmetry in kitaev - type spin models and index theorems on odd manifolds
# Предсказанный заголовок:  phase - of phase potts model
# -----------------------------------
# Оригинальный заголовок:  model misspecification in peaks over threshold analysis
# Предсказанный заголовок:  on the extremal threshold threshold threshold threshold threshold
# -----------------------------------
# Оригинальный заголовок:  phase transition and dissipation driven budding in lipid vesicles
# Предсказанный заголовок:  instability of vesicles in vesicles vesicles
# -----------------------------------
# Оригинальный заголовок:  optimal learning rates for kernel conjugate gradient regression
# Предсказанный заголовок:  convergence rates for kernel least squares squares regression
# -----------------------------------
# Оригинальный заголовок:  long memory and volatility clustering : is the empirical evidence consistent across stock markets ?
# Предсказанный заголовок:  entropic volatility and volatility clustering
# -----------------------------------
# Оригинальный заголовок:  topological gravitation on graph manifolds
# Предсказанный заголовок:  topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological topological
# -----------------------------------
# Оригинальный заголовок:  fast l1-minimization algorithm for sparse approximation based on an improved lpnn - lca framework
# Предсказанный заголовок:  sparse sparse approximation for sparse sparse reconstruction
# -----------------------------------
# Оригинальный заголовок:  multi - objective optimal designs in comparative clinical trials with covariates : the reinforced doubly adaptive biased coin design
# Предсказанный заголовок:  doubly adaptive design of treatment treatment in clinical trials
# -----------------------------------
# Оригинальный заголовок:  optimal siting and sizing of energy storage systems in active distribution networks to achieve their dispatchability
# Предсказанный заголовок:  optimal optimization of power storage systems with a power
# -----------------------------------
# Оригинальный заголовок:  finite size effects in the correlation structure of stochastic neural networks : analysis of different connectivity matrices and failure of the mean - field theory
# Предсказанный заголовок:  firing statistics of neural networks
# -----------------------------------
# Оригинальный заголовок:  direct estimation of firing rates from calcium imaging data
# Предсказанный заголовок:  deconvolution deconvolution of spike train imaging
# -----------------------------------
# Оригинальный заголовок:  investigating diffractive w production in hadron - hadron collisions at high energies
# Предсказанный заголовок:  diffractive diffractive w diffractive w diffractive w diffractive w - hadron colliders
# -----------------------------------
# Оригинальный заголовок:  sequential rank agreement methods for comparison of ranked lists
# Предсказанный заголовок:  ranking of ranked lists
# -----------------------------------
# Оригинальный заголовок:  variational theory of balance systems
# Предсказанный заголовок:  lagrangians and integrability of the - antifield formalism
# -----------------------------------
# Оригинальный заголовок:  extremal problems on triangle areas in two and three dimensions
# Предсказанный заголовок:  minima of minima minima in drawings of drawings of drawings
# -----------------------------------
# Оригинальный заголовок:  hyperkahler and quaternionic kahler manifolds with s^1-symmetries
# Предсказанный заголовок:  quaternionic kahler manifolds quaternionic kahler manifolds kahler manifolds
# -----------------------------------
# Оригинальный заголовок:  uniformisation of foliations by curves
# Предсказанный заголовок:  on of meromorphic functions of meromorphic curves
# -----------------------------------
# Оригинальный заголовок:  vulnerability assessment of power grids based on both topological and electrical properties
# Предсказанный заголовок:  vulnerability of monitoring vulnerability grids : power vulnerability analysis
# -----------------------------------
# Оригинальный заголовок:  operads of compatible structures and weighted partitions
# Предсказанный заголовок:  a structures of the structures
# -----------------------------------
# Оригинальный заголовок:  riemann - christoffel flows
# Предсказанный заголовок:  ricci flow christoffel flows
# -----------------------------------
# Оригинальный заголовок:  speckle patterns and 2-dimensional spatial models
# Предсказанный заголовок:  speckle patterns of the spatial point patterns in the patterns
# -----------------------------------
# Оригинальный заголовок:  magnetocaloric effect in the frustrated square lattice j1-j2 model
# Предсказанный заголовок:  magnetic phases in the frustrated frustrated frustrated j1-j2 model
# -----------------------------------
# Оригинальный заголовок:  dynamic model averaging for practitioners in economics and finance : the edma package
# ...
# Предсказанный заголовок:  on orbits of axisymmetric orbits in the gravitational
# -----------------------------------
# Оригинальный заголовок:  asymptotics and concentration bounds for bilinear forms of spectral projectors of sample covariance
# Предсказанный заголовок:  chernoff bounds for projectors of eigenvectors of projectors of projectors of projectors of projectors
# -----------------------------------
# Оригинальный заголовок:  relations among modular points on elliptic curves
# Предсказанный заголовок:  on of of of elliptic curves
# -----------------------------------
# Оригинальный заголовок:  gamma - ray blazars : the combined agile and magic views
# Предсказанный заголовок:  blazar blazars blazars
# -----------------------------------
# Оригинальный заголовок:  towards end - to - end code - switching speech recognition
# Предсказанный заголовок:  hybrid - - - end - end - end - end speech recognition
# -----------------------------------
# Оригинальный заголовок:  computing exact clustering posteriors with subset convolution
# Предсказанный заголовок:  partition function for clustering clustering
# -----------------------------------
# Оригинальный заголовок:  bayesian structure learning for markov random fields with a spike and slab prior
# Предсказанный заголовок:  bayesian bayesian learning for sparse markov fields
# -----------------------------------
# Оригинальный заголовок:  4d wavelet - based regularization for parallel mri reconstruction : impact on subject and group - levels statistical sensitivity in fmri
# Предсказанный заголовок:  4d - mri reconstruction for mri mri reconstruction
# -----------------------------------
# Оригинальный заголовок:  a robust algorithm for template curve estimation based on manifold embedding
# Предсказанный заголовок:  a approximation of functional registration
# -----------------------------------
# Оригинальный заголовок:  quantifying prosodic variability in middle english alliterative poetry
# Предсказанный заголовок:  prosodic prosodic of <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk>
# -----------------------------------
# Оригинальный заголовок:  conduction electron spin - lattice relaxation time in the mgb2 superconductor
# Предсказанный заголовок:  spin spin spin in the spin spin spin in the magnetic field
# -----------------------------------
# Оригинальный заголовок:  effective gravity from a quantum gauge theory in euclidean space - time
# Предсказанный заголовок:  gauge invariance of the gauge - space
# -----------------------------------
# Оригинальный заголовок:  data - driven rank breaking for efficient rank aggregation
# Предсказанный заголовок:  rank rank rank aggregation
# -----------------------------------
# Оригинальный заголовок:  music of brain and music on brain : a novel eeg sonification approach
# Предсказанный заголовок:  eeg - based brain sonification
# -----------------------------------
# Оригинальный заголовок:  understanding the shape of the halo - mass and galaxy - mass cross - correlation functions
# Предсказанный заголовок:  the millennium halo of the millennium galaxy halo
# -----------------------------------
# Оригинальный заголовок:  parametric estimation of complex mixed models based on meta - model approach
# Предсказанный заголовок:  a - mixed - mixed models
# -----------------------------------
# Оригинальный заголовок:  a hierarchical eigenmodel for pooled covariance estimation
# Предсказанный заголовок:  sparse eigenmodel eigenmodel eigenmodel for eigenmodel covariance eigenmodel
# -----------------------------------
# Оригинальный заголовок:  ef cha : warm dust orbiting a nearby 10 myr old star
# Предсказанный заголовок:  ef cha : the dust spectrograph
# -----------------------------------
# Оригинальный заголовок:  rayleigh imaging of graphene and graphene layers
# Предсказанный заголовок:  graphene graphene microscopy microscopy : mn)as and graphene
# -----------------------------------
# Оригинальный заголовок:  mathematical model for the evaporation of a liquid fuel droplet , subject to nonlinear constraints
# Предсказанный заголовок:  the of of the droplet in a droplet
# -----------------------------------
# Оригинальный заголовок:  effects of economic interactions on credit risk
# Предсказанный заголовок:  the credit risk model
# -----------------------------------
# Оригинальный заголовок:  eigenfunction concentration for polygonal billiards
# Предсказанный заголовок:  billiards billiards billiards
# -----------------------------------
# Оригинальный заголовок:  improving coverage accuracy of block bootstrap confidence intervals
# Предсказанный заголовок:  block bootstrap bootstrap bootstrap bootstrap bootstrap
# -----------------------------------
# Оригинальный заголовок:  logarithmic fourier integrals for the riemann zeta function
# Предсказанный заголовок:  the riemann zeta functions and riemann zeta function
# -----------------------------------
# Оригинальный заголовок:  non - convex rank minimization via an empirical bayesian approach
# Предсказанный заголовок:  robust - rank convex optimization
# -----------------------------------
# Оригинальный заголовок:  real - time electron dynamics with exact - exchange time - dependent density - functional theory
# Предсказанный заголовок:  time - time dependent time - dependent time - dependent potentials
# -----------------------------------
# Оригинальный заголовок:  unsupervised learning in neuromemristive systems
# Предсказанный заголовок:  unsupervised learning for unsupervised learning
# -----------------------------------
# Оригинальный заголовок:  from design to tape - out in scl 180 nm cmos integrated circuit fabrication technology
# Предсказанный заголовок:  <unk> silicon management for silicon 180 180 180 180 nm cmos silicon
# -----------------------------------
# Оригинальный заголовок:  adaptive precision cnn accelerator using radix - x parallel connected memristor crossbars
# Предсказанный заголовок:  adaptive accelerator for accelerator for accelerator for accelerator for deep neural networks
# -----------------------------------
# Оригинальный заголовок:  random colourings of aperiodic graphs : ergodic and spectral properties
# Предсказанный заголовок:  ergodic colourings of random graphs
# -----------------------------------
# Оригинальный заголовок:  a selective approach to internal inference
# Предсказанный заголовок:  selective inference for overcome the dimensional
# -----------------------------------
# Оригинальный заголовок:  direct - coupling analysis of nucleotide coevolution facilitates rna secondary and tertiary structure prediction
# Предсказанный заголовок:  inferring rna - rna motifs using rna -
# -----------------------------------
# Оригинальный заголовок:  are biological neurons that vicious ? or only their models ?
# Предсказанный заголовок:  a - of - - world neural networks
# -----------------------------------
# Оригинальный заголовок:  finite / countable state space stochastic processes : point processes : characterization of associated auto - correlation functions :
# Предсказанный заголовок:  on the of of stochastic processes processes
# -----------------------------------
# Оригинальный заголовок:  rip - based near - oracle performance guarantees for subspace - pursuit , cosamp , and iterative hard - thresholding
# Предсказанный заголовок:  rip guarantees for rip guarantees for rip guarantees
# -----------------------------------
# Оригинальный заголовок:  quasi -- local angular momentum of non -- symmetric isolated and dynamical horizons from the conformal decomposition of the metric
# Предсказанный заголовок:  quasi - local local of the surfaces
# -----------------------------------
# Оригинальный заголовок:  causality inference in stochastic systems from neurons to currencies : profiting from small sample size
# Предсказанный заголовок:  statistical inference of the - of in the - of
# -----------------------------------
# Оригинальный заголовок:  the abelian cosets of the heisenberg group
# Предсказанный заголовок:  on the of model of the - - dimensional model
# -----------------------------------
# Оригинальный заголовок:  non - hermitian von roos hamiltonian 's $ \eta$-weak - pseudo - hermiticity , isospectrality and exact solvability
# Предсказанный заголовок:  pseudo - hermiticity of pseudo - hermitian hamiltonians
# -----------------------------------
# Оригинальный заголовок:  boundary effects on population dynamics in stochastic lattice lotka - volterra models
# Предсказанный заголовок:  competition of the stochastic lotka - volterra predator lotka - volterra model
# -----------------------------------
# Оригинальный заголовок:  using spatial correlation in semi - supervised hyperspectral unmixing under polynomial post - nonlinear mixing model
# Предсказанный заголовок:  semi - supervised unmixing unmixing unmixing
# -----------------------------------
# Оригинальный заголовок:  semiparametric stochastic volatility modelling using penalized splines
# Предсказанный заголовок:  penalized likelihood conditional model for stochastic volatility models
# -----------------------------------
# Оригинальный заголовок:  adaptive long - range migration promotes cooperation under tempting conditions
# Предсказанный заголовок:  adaptive adaptive evolution of cooperation in tempting migration
# -----------------------------------
# Оригинальный заголовок:  density is at most the spread of the square
# Предсказанный заголовок:  boolean functions of boolean functions
# -----------------------------------
# Оригинальный заголовок:  exciting the magnetosphere of the magnetar cxou j164710.2 - 455216 in westerlund 1
# Предсказанный заголовок:  x - ray millisecond pulsar 1e <unk> <unk> magnetar <unk> magnetar <unk>
# -----------------------------------
# Оригинальный заголовок:  does k matter ? k - nn hubness analysis for kernel additive modelling vocal separation
# Предсказанный заголовок:  a - based model for additive models
# -----------------------------------
# Оригинальный заголовок:  how many imputations do you need ? a two - stage calculation using a quadratic rule
# Предсказанный заголовок:  reducing offline evaluation of imputations imputations
# -----------------------------------
# Оригинальный заголовок:  conditional strategies and the evolution of cooperation in spatial public goods games
# Предсказанный заголовок:  evolutionary aversion in cooperation in cooperation
# -----------------------------------
# Оригинальный заголовок:  star cluster " infant mortality " in the small magellanic cloud ( redivivus )
# Предсказанный заголовок:  the the of the cluster magellanic cluster
# -----------------------------------
# Оригинальный заголовок:  moduli stabilization in 5d gauged supergravity with universal hypermultiplet and boundary superpotentials
# Предсказанный заголовок:  gauged supergravity supergravity supergravity supergravity supergravity
# -----------------------------------
# Оригинальный заголовок:  inference on difference of means of two log - normal distributions ; a generalized approach
# Предсказанный заголовок:  testing the log - normal normal - normal -
# -----------------------------------
# Оригинальный заголовок:  quarkonium production in coherent pp / aa collisions and small - x physics
# Предсказанный заголовок:  diffractive parton production in hadron colliders
# -----------------------------------
# Оригинальный заголовок:  studies on optimizing potential energy functions for maximal intrinsic hyperpolarizability
# Предсказанный заголовок:  on the of of energy hyperpolarizability in hyperpolarizability
# -----------------------------------
# Оригинальный заголовок:  the distribution of the maximum of a second order autoregressive process : the continuous case
# Предсказанный заголовок:  on the of the the of the the of the first order gaussian process
# -----------------------------------
# Оригинальный заголовок:  empirical constraints on vacuum decay in the stringy landscape
# Предсказанный заголовок:  instanton vacuum and the vacuum
# -----------------------------------
# Оригинальный заголовок:  risk estimation for matrix recovery with spectral regularization
# Предсказанный заголовок:  a matrix matrix matrix for matrix matrix
# -----------------------------------
# Оригинальный заголовок:  benchmarking historical corporate performance
# Предсказанный заголовок:  bayesian bayesian analysis of bayesian bayesian analysis
# -----------------------------------
# Оригинальный заголовок:  harmonic analysis on local fields and adelic spaces i
# Предсказанный заголовок:  harmonic transform of the fields
# -----------------------------------
# Оригинальный заголовок:  tipping diffusivity in information accumulation systems : more links , less consensus
# Предсказанный заголовок:  the - of interaction in the - community
# -----------------------------------
# Оригинальный заголовок:  decomposition tables for experiments . ii . two -- one randomizations
# Предсказанный заголовок:  on tables of randomizations
# -----------------------------------
# Оригинальный заголовок:  discussion of " sequential quasi - monte carlo " by mathieu gerber and nicolas chopin
# Предсказанный заголовок:  variance mathieu auxiliary monte carlo monte carlo monte carlo monte carlo
# -----------------------------------
# Оригинальный заголовок:  unifying markov properties for graphical models
# Предсказанный заголовок:  markov markov models
# -----------------------------------
# Оригинальный заголовок:  lepton universality tests with kaons
# Предсказанный заголовок:  review of the physics of the physics
# -----------------------------------
# Оригинальный заголовок:  using supervised learning to improve monte carlo integral estimation
# Предсказанный заголовок:  monte carlo methods for monte carlo
# -----------------------------------
# Оригинальный заголовок:  convex modeling of interactions with strong heredity
# Предсказанный заголовок:  convex convex optimization for a heredity
# -----------------------------------
# Оригинальный заголовок:  empirical risk minimization is consistent with the mean absolute percentage error
# Предсказанный заголовок:  absolute percentage error absolute percentage error absolute percentage error regression
# -----------------------------------
# Оригинальный заголовок:  input - output relations in biological systems : measurement , information and the hill equation
# Предсказанный заголовок:  a - of biological systems
# -----------------------------------
# Оригинальный заголовок:  technical note : approximate bayesian parameterization of a process - based tropical forest model
# Предсказанный заголовок:  approximate bayesian pseudo - parametric bayesian estimation for tropical hierarchical models
# -----------------------------------
# Оригинальный заголовок:  semi - supervised k - means++
# Предсказанный заголовок:  semi - supervised means++ means++ means++ means++ means++ means++
# -----------------------------------
# Оригинальный заголовок:  novel algorithms based on majorization minimization for nonnegative matrix factorization
# Предсказанный заголовок:  alternating nonnegative matrix nonnegative matrix factorization nonnegative matrix factorization nonnegative matrix factorization
# -----------------------------------
# Оригинальный заголовок:  design principles and optimal performance for molecular motors under realistic constraints
# Предсказанный заголовок:  switching switching in motor motors motor motor motor
# -----------------------------------
# Оригинальный заголовок:  nonparametric quantile regression for twice censored data
# Предсказанный заголовок:  quantile quantile regression quantile regression quantile regression
# -----------------------------------
# Оригинальный заголовок:  geodesic curvature driven surface microdomain formation
# Предсказанный заголовок:  curvature curvature curvature in lipid bilayer lipid bilayer lipid bilayer lipid bilayer lipid bilayer
# -----------------------------------
# Оригинальный заголовок:  on capillary - gravity waves generated by a slow moving object
# Предсказанный заголовок:  capillary waves in the - - - - - - - -
# -----------------------------------

# %%
example_idx = 112

src = vars(valid_data.examples[example_idx])['src']
trg = vars(valid_data.examples[example_idx])['trg']

print(f'src = {src}')
print(f'trg = {trg}')
# Out:
# src = ['these', 'are', 'the', 'proceedings', 'of', 'the', '13th', 'workshop', 'on', 'algorithms', 'in', 'bioinformatics', ',', 'wabi2013', ',', 'which', 'was', 'held', 'september', '2', '-', '4', '2013', 'in', 'sophia', 'antipolis', ',', 'france', '.', 'all', 'manuscripts', 'were', 'peer', 'reviewed', 'by', 'the', 'wabi2013', 'program', 'committee', 'and', 'external', 'reviewers', '.']
# trg = ['proceedings', 'of', 'the', '13th', 'workshop', 'on', 'algorithms', 'in', 'bioinformatics', '(', 'wabi2013', ')']

# %%
translation, attention = translate_sentence(model, src)

print(f'predicted trg = {translation}')

display_attention(src, translation, attention)
# Out:
# predicted trg = ['proceedings', 'of', 'the', 'papers', 'on', 'the', 'mathematics']

# %%
example_idx = 10

src = vars(valid_data.examples[example_idx])['src']
trg = vars(valid_data.examples[example_idx])['trg']

print(f'src = {src}')
print(f'trg = {trg}')
# Out:
# src = ['proper', 'balance', 'between', 'exploitation', 'and', 'exploration', 'is', 'what', 'makes', 'good', 'decisions', ',', 'which', 'achieve', 'high', 'rewards', 'like', 'payoff', 'or', 'evolutionary', 'fitness', '.', 'the', 'infomax', 'principle', 'postulates', 'that', 'maximization', 'of', 'information', 'directs', 'the', 'function', 'of', 'diverse', 'systems', ',', 'from', 'living', 'systems', 'to', 'artificial', 'neural', 'networks', '.', 'while', 'specific', 'applications', 'are', 'successful', ',', 'the', 'validity', 'of', 'information', 'as', 'a', 'proxy', 'for', 'reward', 'remains', 'unclear', '.', 'here', ',', 'we', 'consider', 'the', 'multi', '-', 'armed', 'bandit', 'decision', 'problem', ',', 'which', 'features', 'arms', '(', 'slot', '-', 'machines', ')', 'of', 'unknown', 'probabilities', 'of', 'success', 'and', 'a', 'player', 'trying', 'to', 'maximize', 'cumulative', 'payoff', 'by', 'choosing', 'the', 'sequence', 'of', 'arms', 'to', 'play', '.', 'we', 'show', 'that', 'an', 'infomax', 'strategy', '(', 'info', '-', 'p', ')', 'which', 'optimally', 'gathers', 'information', 'on', 'the', 'highest', 'mean', 'reward', 'among', 'the', 'arms', 'saturates', 'known', 'optimal', 'bounds', 'and', 'compares', 'favorably', 'to', 'existing', 'policies', '.', 'the', 'highest', 'mean', 'reward', 'considered', 'by', 'info', '-', 'p', 'is', 'not', 'the', 'quantity', 'actually', 'needed', 'for', 'the', 'choice', 'of', 'the', 'arm', 'to', 'play', ',', 'yet', 'it', 'allows', 'for', 'optimal', 'tradeoffs', 'between', 'exploration', 'and', 'exploitation', '.']
# trg = ['infomax', 'strategies', 'for', 'an', 'optimal', 'balance', 'between', 'exploration', 'and', 'exploitation']

# %%
translation, attention = translate_sentence(model, src)

print(f'predicted trg = {translation}')

display_attention(src, translation, attention)
# Out:
# predicted trg = ['infomax', 'exploration', 'of', 'exploitation', 'strategies', 'for', 'exploitation', 'strategies']

# %% [markdown]
# ### Считаем BLEU

# %%
import nltk

n_gram_weights = [0.3334, 0.3333, 0.3333]

# %%
test_len = len(valid_data)

# %%
original_texts = []
generated_texts = []
macro_bleu = 0

for example_idx in range(test_len):
    src = vars(valid_data.examples[example_idx])['src']
    trg = vars(valid_data.examples[example_idx])['trg']
    translation, _ = translate_sentence(model, src)

    original_texts.append(trg)
    generated_texts.append(translation)

    bleu_score = nltk.translate.bleu_score.sentence_bleu(
        [trg],
        translation,
        weights = n_gram_weights
    )    
    macro_bleu += bleu_score

macro_bleu /= test_len
# Out:
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 3-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
# averaging sentence-level BLEU (i.e. macro-average precision)
print('Macro-average BLEU (LSTM): {0:.5f}'.format(macro_bleu))
# Out:
# Macro-average BLEU (LSTM): 0.28569

# %% [markdown]
# ### Делаем submission в Kaggle

# %%
import pandas as pd

submission_data = pd.read_csv('input/test.csv')
abstracts = submission_data['abstract'].values

# %% [markdown]
# Генерация заголовков для тестовых данных:

# %%
titles = []
for abstract in abstracts:
    title, _ = translate_sentence(model, abstract.split())
    titles.append(' '.join(title).replace('<unk>', ''))

# %% [markdown]
# Записываем полученные заголовки в файл формата `<abstract>,<title>`:

# %%
submission_df = pd.DataFrame({'abstract': abstracts, 'title': titles})
submission_df.to_csv('predicted_titles.csv', index=False)

# %% [markdown]
# С помощью функции `generate_csv` приводим файл `submission_prediction.csv` в формат, необходимый для посылки в соревнование на Kaggle:

# %%
import string
from nltk.util import ngrams
import numpy as np
import pandas as pd
import pickle


def generate_csv(input_file='predicted_titles.csv',
                 output_file='submission.csv',
                 voc_file='vocs.pkl'):
    '''
    Generates file in format required for submitting result to Kaggle
    
    Parameters:
        input_file (str) : path to csv file with your predicted titles.
                           Should have two fields: abstract and title
        output_file (str) : path to output submission file
        voc_file (str) : path to voc.pkl file
    '''
    data = pd.read_csv(input_file)
    with open(voc_file, 'rb') as voc_file:
        vocs = pickle.load(voc_file)

    with open(output_file, 'w') as res_file:
        res_file.write('Id,Predict\n')
        
    output_idx = 0
    for row_idx, row in data.iterrows():
        trg = row['title']
        trg = trg.translate(str.maketrans('', '', string.punctuation)).lower().split()
        trg.extend(['_'.join(ngram) for ngram in list(ngrams(trg, 2)) + list(ngrams(trg, 3))])
        
        VOCAB_stoi = vocs[row_idx]
        trg_intersection = set(VOCAB_stoi.keys()).intersection(set(trg))
        trg_vec = np.zeros(len(VOCAB_stoi))    

        for word in trg_intersection:
            trg_vec[VOCAB_stoi[word]] = 1

        with open(output_file, 'a') as res_file:
            for is_word in trg_vec:
                res_file.write('{0},{1}\n'.format(output_idx, int(is_word)))
                output_idx += 1


generate_csv()
